# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from astropy.table import Table
from astropy.io import ascii
from astropy.io import fits

# %%
x= np.arange(0,2*np.pi,.001)
y= np.sin(x)
plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.show()

# %%
z=np.arange(0,2*np.pi,.001)
w=np.cos(z)
plt.plot(z,w)
plt.xlabel('x')
plt.ylabel('cos(x)')
plt.show()

# %%
x=np.linspace(0,2*np.pi,1000)
y=np.sin(x)

data = Table([x,y],names=['x','sin(x)'])
ascii.write(data,'Table1.txt',format='commented_header')
data_in=ascii.read('Table1.txt')
print(data_in)
# Out:
#          x                    sin(x)
# -------------------- -----------------------
#                  0.0                     0.0
# 0.006289474781961547    0.006289433316067751
# 0.012578949563923095    0.012578617838741058
# 0.018868424345884642     0.01886730478446709
#  0.02515789912784619    0.025155245389375847
#  0.03144737390980774      0.0314421909191206
# 0.037736848691769284     0.03772789267871718
#  0.04402632347373083     0.04401210202238166
#  0.05031579825569238     0.05029457036336619
# 0.056605273037653926     0.05657504918379235
#                  ...                     ...
#     6.22029055935997    -0.06285329004448273
#    6.226580034141932    -0.05657504918379272
#    6.232869508923893   -0.050294570363367035
#    6.239158983705855    -0.04401210202238211
#    6.245448458487816     -0.0377278926787181
#    6.251737933269778   -0.031442190919121114
#    6.258027408051739   -0.025155245389376843
#    6.264316882833701   -0.018867304784467676
# ...

# %%
z=np.linspace(0,2*np.pi,1000)
w=np.cos(z)

data = Table([x,y],names=['x','cos(x)'])
ascii.write(data,'Table2.txt',format='commented_header')
data_in=ascii.read('Table2.txt')
print(data_in)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[14], line 5
#       2 w=np.cos(z)
#       4 data = Table([x,y],names=['x','cos(x)'])
# ----> 5 ascii.write(data,'Table2.txt',format='commented_header')
#       6 data_in=ascii.read('Table2.txt')
#       7 print(data_in)
#
# File /cm/shared/apps/python/3.10.12/lib/python3.10/site-packages/astropy/io/ascii/ui.py:941, in write(table, output, format, Writer, fast_writer, overwrite, **kwargs)
#     939     output = os.path.expanduser(output)
#     940     if not overwrite and os.path.lexists(output):
# --> 941         raise OSError(NOT_OVERWRITING_MSG.format(output))
#     943 if output is None:
#     944     output = sys.stdout
#
# OSError: File Table2.txt already exists. If you mean to replace it then use the argument "overwrite=True".

# %%
x_values = np.linspace(0, 2 * np.pi, 100)

# Calculate sine and cosine values
sine_values = np.sin(x_values)
cosine_values = np.cos(x_values)

# Print the first 10 values in columns
print(f"{'x (radians)'}, {'sin(x)'}, {'cos(x)'}")

for i in range(10):
    print(f"{x_values[i]}, {sine_values[i]}, {cosine_values[i]}")
# Out:
# x (radians), sin(x), cos(x)
# 0.0, 0.0, 1.0
# 0.06346651825433926, 0.0634239196565645, 0.9979866764718843
# 0.12693303650867852, 0.12659245357374926, 0.9919548128307951
# 0.1903995547630178, 0.18925124436041024, 0.9819286972627068
# 0.25386607301735703, 0.2511479871810792, 0.9679487013963565
# 0.3173325912716963, 0.3120334456984871, 0.9500711177409454
# 0.3807991095260356, 0.3716624556603276, 0.9283679330160726
# 0.4442656277803748, 0.42979491208917164, 0.902926538286621
# 0.5077321460347141, 0.48619673610046865, 0.8738493770697848
# 0.5711986642890533, 0.5406408174555974, 0.8412535328311812
